# %% [markdown]
# EBAY CAR SALES is a website platform for putting your car for sale
# In this project we will clean the ebay car dataset and anayse it later.

# %%
import pandas as pd
import numpy as np

# %%
autos = pd.read_csv("autos.csv", encoding = "Latin-1")

# %%
autos
# Out:
#                 dateCrawled  \
# 0       2016-03-24 11:52:17
# 1       2016-03-24 10:58:45
# 2       2016-03-14 12:52:21
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# 5       2016-04-04 17:36:23
# 6       2016-04-01 20:48:51
# 7       2016-03-21 18:54:38
# 8       2016-04-04 23:42:13
# 9       2016-03-17 10:53:50
# 10      2016-03-26 19:54:18
# 11      2016-04-07 10:06:22
# 12      2016-03-15 22:49:09
# 13      2016-03-21 21:37:40
# 14      2016-03-21 12:57:01
# 15      2016-03-11 21:39:15
# 16      2016-04-01 12:46:46
# 17      2016-03-20 10:25:19
# 18      2016-03-23 15:48:05
# 19      2016-04-01 22:55:47
# 20      2016-04-01 19:56:48
# 21      2016-03-27 11:38:00
# 22      2016-03-23 14:52:51
# 23      2016-03-12 19:43:07
# 24      2016-03-13 20:40:49
# 25      2016-03-18 21:44:09
# 26      2016-03-10 19:38:18
# 27      2016-03-07 12:51:23
# 28      2016-03-09 11:56:38
# 29      2016-03-08 19:55:19
# ...                     ...
# 371498  2016-03-11 15:50:38
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
# dateCrawled            371528 non-null object
# name                   371528 non-null object
# seller                 371528 non-null object
# offerType              371528 non-null object
# price                  371528 non-null int64
# abtest                 371528 non-null object
# vehicleType            333659 non-null object
# yearOfRegistration     371528 non-null int64
# gearbox                351319 non-null object
# powerPS                371528 non-null int64
# model                  351044 non-null object
# kilometer              371528 non-null int64
# monthOfRegistration    371528 non-null int64
# fuelType               338142 non-null object
# brand                  371528 non-null object
# notRepairedDamage      299468 non-null object
# dateCreated            371528 non-null object
# nrOfPictures           371528 non-null int64
# ...

# %% [markdown]
# The dataset has 50,000 rows and 20 columns
# It contains columns that have null values
# Also, the columns are written in Camel case instead of snakecase

# %%
autos.columns
# Out:
# Index([u'dateCrawled', u'name', u'seller', u'offerType', u'price', u'abtest',
#        u'vehicleType', u'yearOfRegistration', u'gearbox', u'powerPS', u'model',
#        u'kilometer', u'monthOfRegistration', u'fuelType', u'brand',
#        u'notRepairedDamage', u'dateCreated', u'nrOfPictures', u'postalCode',
#        u'lastSeen'],
#       dtype='object')

# %%
autos.rename({"yearOfRegistration":"registration_year","monthOfRegistration":"registration_month","notRepairedDamage": "unrepaired_damage"
,"dateCreated": "ad_created"}, axis = 1, inplace = True)

# %%
new_columns = []
for column in autos.columns:
    c = column.lower()
    new_columns.append(c)
autos.columns = new_columns    
autos.columns
# Out:
# Index([       u'datecrawled',               u'name',             u'seller',
#                 u'offertype',              u'price',             u'abtest',
#               u'vehicletype',  u'registration_year',            u'gearbox',
#                   u'powerps',              u'model',          u'kilometer',
#        u'registration_month',           u'fueltype',              u'brand',
#         u'unrepaired_damage',         u'ad_created',       u'nrofpictures',
#                u'postalcode',           u'lastseen'],
#       dtype='object')

# %%
autos.describe(include = 'all')
# Out:
#                 datecrawled         name  seller offertype         price  \
# count                371528       371528  371528    371528  3.715280e+05
# unique               280500       233531       2         2           NaN
# top     2016-03-24 14:49:47  Ford_Fiesta  privat   Angebot           NaN
# freq                      7          657  371525    371516           NaN
# mean                    NaN          NaN     NaN       NaN  1.729514e+04
# std                     NaN          NaN     NaN       NaN  3.587954e+06
# min                     NaN          NaN     NaN       NaN  0.000000e+00
# 25%                     NaN          NaN     NaN       NaN  1.150000e+03
# 50%                     NaN          NaN     NaN       NaN  2.950000e+03
# 75%                     NaN          NaN     NaN       NaN  7.200000e+03
# max                     NaN          NaN     NaN       NaN  2.147484e+09
#
#         abtest vehicletype  registration_year  gearbox        powerps   model  \
# ...

# %% [markdown]
# Our initial observations:
#
# There are a number of text columns where all (or nearly all) of the values are the same:
# seller
# offer_type
# The num_photos column has only one value i.e. 0, we need to remove this column
# Also, other columns such as price and odometer should be integers

# %%
autos["price"].head()
# Out:
# 0      480
# 1    18300
# 2     9800
# 3     1500
# 4     3600
# Name: price, dtype: int64

# %% [markdown]
# This should be in integers for better analysis

# %%
autos["price"] = (autos["price"]
                          .str.replace("$","")
                          .str.replace(",","")
                          .astype(int)
                          )
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-21-9dd738bbbaa1> in <module>()
# ----> 1 autos["price"] = (autos["price"]
#       2                           .str.replace("$","")
#       3                           .str.replace(",","")
#       4                           .astype(int)
#       5                           )
#
# C:\Users\Dheeraj Kafaltia\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# C:\Users\Dheeraj Kafaltia\Anaconda2\lib\site-packages\pandas\core\accessor.pyc in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
autos.price.head()

# %%
autos["odometer"] = (autos["odometer"]
                          .str.replace("km","")
                          .str.replace(",","")
                          .astype(int)
                          )

# %%
autos.rename({"odometer":"odometer_km"},axis =1, inplace = True)
autos.odometer_km.head()

# %%
print(autos["seller"].value_counts())
print(autos["offertype"].value_counts())

# %% [markdown]
# The column "seller" and "offertype" have only one value throughout and not required as well

# %%
autos = autos.drop(["nrofpictures","seller","offertype"], axis = 1)

# %% [markdown]
# Till now, we have cleaned the columns not required as well as made the columns from object to integer type
# Now, we will try to find outliers or wrong data entries in the data

# %%
price = autos["price"]
print("No of unique prices:", price.unique().shape)
print(autos["price"].describe())
print(autos["price"].value_counts().sort_index(ascending = False).head(20))
print(autos["price"].value_counts().sort_index(ascending = True).head(20))

# %% [markdown]
# There are a number of listings with prices below \$30, including about 1,500 at \$0. There are also a small number of listings with very high values, including 14 at around or over $1 million.
#
# Given that eBay is an auction site, there could legitimately be items where the opening bid is \$1. We will keep the \$1 items, but remove anything above \$350,000, since it seems that prices increase steadily to that number and then jump up to less realistic numbers.

# %%
autos = autos[(autos["price"] <= 350000) & (autos["price"] > 0)]
autos["price"].value_counts().sort_index().head()

# %%
autos["odometer_km"].value_counts()

# %% [markdown]
# This table looks like has been rounded and the site itself might hva provided these optons as rounded, so we dont need to do anythiing with this data
# Also, there are more vicheles with reading greater than 150000 km

# %%
autos.columns

# %% [markdown]
# As, this is a car selling website so the adds created, crawled or last seen can be taken as just dates and the dates can be extracted from the string for better analysis

# %%
autos["datecrawled"] = autos["datecrawled"].str[:10]
autos["ad_created"] = autos["ad_created"].str[:10]
autos["lastseen"] = autos["lastseen"].str[:10]

# %%
print(autos["datecrawled"]
      .value_counts(normalize=True,dropna=False)
      .sort_index())
print(autos["datecrawled"]
      .value_counts(normalize=True,dropna=False)
      .sort_values())

# %% [markdown]
# Looks like the site was crawled daily over roughly a one month period in March and April 2016. The distribution of listings crawled on each day is roughly uniform.

# %%
print(autos["ad_created"]
      .value_counts(normalize=True,dropna=False)
      .sort_index())
print(autos["ad_created"]
      .value_counts(normalize=True,dropna=False)
      .sort_values())

# %% [markdown]
# There is a large variety of ad created dates. Most fall within 1-2 months of the listing date, but a few are quite old, with the oldest at around 9 months.

# %%
print(autos["lastseen"]
      .value_counts(normalize=True,dropna=False)
      .sort_index())
print(autos["lastseen"]
      .value_counts(normalize=True,dropna=False)
      .sort_values())

# %% [markdown]
# The crawler recorded the date it last saw any listing, which allows us to determine on what day a listing was removed, presumably because the car was sold.
#
# The last three days contain a disproportionate amount of 'last seen' values. Given that these are 6-10x the values from the previous days, it's unlikely that there was a massive spike in sales, and more likely that these values are to do with the crawling period ending and don't indicate car sales.

# %%
print(autos["registration_year"].describe())
autos["registration_year"].dtype

# %% [markdown]
# The registration year for veichles should be between 1900 to 2016, it cannot exceed 2016 and it very rare to find a motor vechile of 1800's
# So, we will remove all rows with values that dont fit in the range

# %%
#from describe column the total registration values are 50,000
(~autos["registration_year"].between(1900,2016)).sum()*100 / autos.shape[0]

# %% [markdown]
# The total value of data not falling in range is about 4%. So, we can remove the data present

# %%
autos = autos[autos["registration_year"].
                                   between(1900,2016)]
autos["registration_year"].describe()

# %%
autos["registration_year"].value_counts(normalize = True).head(10)

# %%
print(autos["brand"].value_counts(normalize = True))

# %% [markdown]
# German manufacturers represent four out of the top five brands, almost 50% of the overall listings. Volkswagen is by far the most popular brand, with approximately double the cars for sale of the next two brands combined.
#
# There are lots of brands that don't have a significant percentage of listings, so we will limit our analysis to brands representing more than 5% of total listings.

# %%
brand_counts = autos["brand"].value_counts(normalize = True)
common_brands = brand_counts[brand_counts > .05].index
print(common_brands)

# %%
brand_mean_prices = {}

for brand in common_brands:
    brand_only = autos[autos["brand"] == brand]
    mean_price = brand_only["price"].mean()
    brand_mean_prices[brand] = int(mean_price)

brand_mean_prices

# %% [markdown]
# Of the top 5 brands, there is a distinct price gap:
#
# Audi, BMW and Mercedes Benz are more expensive
# Ford and Opel are less expensive
# Volkswagen is in between - this may explain its popularity, it may be a 'best of 'both worlds' option.

# %%
brand_mean_reading = {}

for brand in common_brands:
    brand_only = autos[autos["brand"] == brand]
    mean_reading = brand_only["odometer_km"].mean()
    brand_mean_reading[brand] = int(mean_reading)

brand_mean_reading

# %%
brand_price = pd.Series(brand_mean_prices)
brand_reading = pd.Series(brand_mean_reading)
df = pd.DataFrame(brand_price,columns = ["mean_price"])
df["mean_reading"] = brand_reading
df.sort_values("mean_price", ascending = False)

# %% [markdown]
# The range of car mileages does not vary as much as the prices do by brand, instead all falling within 10% for the top brands. There is a slight trend to the more expensive vehicles having higher mileage, with the less expensive vehicles having lower mileage.
