# %%
# import numpy as np 
import pandas as pd

# %%
litreracy = pd.read_csv('2015_16_Statewise_Secondary.csv')

# %%
litreracy.head()
# Out:
#    ac_year  statcd           statname  area_sqkm  tot_population  \
# 0  2015-16       1  Jammu And Kashmir   222236.0        12548.93
# 1  2015-16       2   Himachal Pradesh    55673.0         6856.51
# 2  2015-16       3             Punjab    50362.0        27704.24
# 3  2015-16       4         Chandigarh      114.0         1054.69
# 4  2015-16       5        Uttarakhand    53483.0        10116.75
#
#    urban_population  grwoth_rate  sexratio  sc_population  st_population  \
# 0             20.05        23.71     883.0            7.4           11.9
# 1              8.69        12.81     974.0           25.2            5.7
# 2             29.82        13.73     893.0           31.9            0.0
# 3             76.66        17.10     818.0           18.9            0.0
# 4             21.54        19.17     963.0           18.8            2.9
#
#      ...     tchmed_nr  tchoth_nr  tchse_nr  tchnr_nr  enrc7_py  enrc8_py  \
# ...

# %%
column = litreracy.columns[0:18]
rename_col = column.str.strip().str.lower()
dict = {}
j=0
for i in column:
    dict[i] = rename_col[j]
    j+=1

# %%
litreracy.rename(dict, inplace = True)
lit_new = litreracy.iloc[:,0:18]
lit_new.head()
# Out:
#    ac_year  statcd           statname  area_sqkm  tot_population  \
# 0  2015-16       1  Jammu And Kashmir   222236.0        12548.93
# 1  2015-16       2   Himachal Pradesh    55673.0         6856.51
# 2  2015-16       3             Punjab    50362.0        27704.24
# 3  2015-16       4         Chandigarh      114.0         1054.69
# 4  2015-16       5        Uttarakhand    53483.0        10116.75
#
#    urban_population  grwoth_rate  sexratio  sc_population  st_population  \
# 0             20.05        23.71     883.0            7.4           11.9
# 1              8.69        12.81     974.0           25.2            5.7
# 2             29.82        13.73     893.0           31.9            0.0
# 3             76.66        17.10     818.0           18.9            0.0
# 4             21.54        19.17     963.0           18.8            2.9
#
#    literacy_rate  male_literacy_rate  female_literacy_rate  distcd  blkcd  \
# ...

# %%
lit_new = lit_new[lit_new['literacy_rate'].notnull()]
lit_new.isnull().sum()
# Out:
# ac_year                 0
# statcd                  0
# statname                0
# area_sqkm               0
# tot_population          0
# urban_population        0
# grwoth_rate             0
# sexratio                0
# sc_population           0
# st_population           0
# literacy_rate           0
# male_literacy_rate      0
# female_literacy_rate    0
# distcd                  0
# blkcd                   0
# villages                0
# clusters                0
# schools                 0
# dtype: int64

# %%
lit_new['statname'].value_counts().sum()
# Out:
# 35

# %%
lit_new.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicate rows are present in the dataset

# %%
# %matplotlib inline
lit_new_sort = lit_new.sort_values('literacy_rate')
lit_new_sort.plot(x = 'statname', y = 'literacy_rate', kind = 'bar',figsize = (18,10),rot = 35b)

# %% [markdown]
# Clealry, we can see that kerela has highest while bihar has lowest literacy rate
